# %% [markdown]
# # Student Alcohol Consumption

# %%
# importando bibliotecas basicas
import pandas as pd
import numpy as np
import plotly
import plotly.plotly as ply
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='EulleSilva', api_key='udHtcUnAQHA1wNwQ1f1Q')

# %% [markdown]
# ## Importando datasets

# %%
# Upload do dataset da turma de matemática
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-90-051401628bef> in <module>()
#       1 # Upload do dataset da turma de matemática
# ----> 2 from google.colab import files
#       3 uploaded = files.upload()
#       4 for fn in uploaded.keys():
#       5   print('User uploaded file "{name}" with length {length} bytes'.format(
#
# ModuleNotFoundError: No module named 'google'

# %%
# Upload do dataset da turma de portugues
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-91-095a97fcac5c> in <module>()
#       1 # Upload do dataset da turma de portugues
# ----> 2 from google.colab import files
#       3 uploaded = files.upload()
#       4 for fn in uploaded.keys():
#       5   print('User uploaded file "{name}" with length {length} bytes'.format(
#
# ModuleNotFoundError: No module named 'google'

# %%
# Importando dataset da turma de matemática
math_students = pd.read_csv("datasets/student-mat.csv",)

# %%
# Importando dataset da turma de matemática
port_students = pd.read_csv("datasets/student-por.csv",)

# %% [markdown]
# ## Deletar colunas que não serão utilizadas

# %%
# Deletar colunas do dataset dos estudantes de Matématica
math_students.drop(math_students.loc[:,['Mjob','Fjob','school','reason','traveltime','paid','nursery']],axis=1,inplace=True)
math_students.columns
# Deletar colunas do datasets/taset dos estudantes de Português
port_students.drop(port_students.loc[:,['Mjob','Fjob','school','reason','traveltime','paid','nursery']],axis=1,inplace=True)
port_students.columns
# Out:
# Index(['sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'guardian', 'studytime', 'failures', 'schoolsup', 'famsup',
#        'activities', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Adicionar coluna 'student_id'

# %%
# Alunos de Matemática
math_students['student_id'] = pd.Series(list(range(0,395)))
cols = math_students.columns.tolist()
a , b = cols.index('sex'), cols.index('student_id')
cols[b] , cols[a] = cols[a] , cols[b]
math_students = math_students[cols]
#math_students

#math_students.to_csv('math_students.csv', sep='\t', encoding='utf-8')

# Alunos de Português
port_students['student_id'] = pd.Series(list(range(0,649)))
cols2 = port_students.columns.tolist()
a , b = cols2.index('sex'), cols2.index('student_id')
cols2[b] , cols2[a] = cols2[a] , cols2[b]
port_students = port_students[cols]
port_students
#port_students.to_csv('port_students.csv', sep='\t', encoding='utf-8')
# Out:
#      student_id  age address famsize Pstatus  Medu  Fedu guardian  studytime  \
# 0             0   18       U     GT3       A     4     4   mother          2
# 1             1   17       U     GT3       T     1     1   father          2
# 2             2   15       U     LE3       T     1     1   mother          2
# 3             3   15       U     GT3       T     4     2   mother          3
# 4             4   16       U     GT3       T     3     3   father          2
# 5             5   16       U     LE3       T     4     3   mother          2
# 6             6   16       U     LE3       T     2     2   mother          2
# 7             7   17       U     GT3       A     4     4   mother          2
# 8             8   15       U     LE3       A     3     2   mother          2
# 9             9   15       U     GT3       T     3     4   mother          2
# 10           10   15       U     GT3       T     4     4   mother          2
# ...

# %% [markdown]
# ## Analisando as caracteristicas dos datasets

# %%
# Verificando variaveis da turma de matemática
math_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
port_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# ...

# %%
math_students.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
port_students.head(5)

# %%
math_students.shape
# Out:
# (395, 26)

# %%
port_students.shape
# Out:
# (649, 26)

# %% [markdown]
# ## Estudantes de Matemática

# %%
# Verificar a distribuição de homens e mulheres
masc = len(math_students[math_students['sex'] == 'F'])
fem = len(math_students[math_students['sex'] == 'M'])
labels = ['Masculino','Feminino']
values = [masc,fem]
colors = ['#96D38C','#E1396C']
trace = go.Pie(labels=labels,values=values,
              hoverinfo='label+percent',textinfo='value',
              textfont=dict(size=20),
              marker=dict(colors=colors,
                         line=dict(color='#000000',width=2)))
ply.iplot([trace],filename='Estudantes de Matématica')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~EulleSilva/2.embed" height="525px" width="100%"></iframe>

# %%
# Consumo de álcool em dias de trabalho 
masc_consumption = math_students[math_students['sex'] == 'M']
#masc_consumption
port_consumption = port_students[port_students['sex'] == 'F']
port_consumption
# Consumo de álcool no final de semana
# Out:
#     sex  age address famsize Pstatus  Medu  Fedu guardian  studytime  \
# 0     F   18       U     GT3       A     4     4   mother          2
# 1     F   17       U     GT3       T     1     1   father          2
# 2     F   15       U     LE3       T     1     1   mother          2
# 3     F   15       U     GT3       T     4     2   mother          3
# 4     F   16       U     GT3       T     3     3   father          2
# 7     F   17       U     GT3       A     4     4   mother          2
# 10    F   15       U     GT3       T     4     4   mother          2
# 11    F   15       U     GT3       T     2     1   father          3
# 15    F   16       U     GT3       T     4     4   mother          1
# 16    F   16       U     GT3       T     4     4   mother          3
# 17    F   16       U     GT3       T     3     3   mother          2
# 24    F   15       R     GT3       T     2     4   mother          3
# 25    F   16       U     GT3       T     2     2   mother          1
# ...

# %% [markdown]
# ## Estudantes de Portugues

# %%
# Verificar a distribuição de homens e mulheres
masc = len(port_students[port_students['sex'] == 'F'])
fem = len(port_students[port_students['sex'] == 'M'])
labels = ['Masculino','Feminino']
values = [masc,fem]
colors = ['#96D38C','#E1396C']
trace = go.Pie(labels=labels,values=values,
              hoverinfo='label+percent',textinfo='value',
              textfont=dict(size=20),
              marker=dict(colors=colors,
                         line=dict(color='#000000',width=2)))
ply.iplot([trace],filename='TATAT')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~EulleSilva/0 or inside your plot.ly account where it is named 'TATAT'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~EulleSilva/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Unindo datasets

# %% [markdown]
# ### Problemas iniciais
#
# Como os datasets tem tamanhos diferentes é necessario normalizar mantendo a proporção e igualdade entre os dados, para isso tomamos o cuidade de manter a mesma quantidade de estudantes com idades iguais em ambos datasets
